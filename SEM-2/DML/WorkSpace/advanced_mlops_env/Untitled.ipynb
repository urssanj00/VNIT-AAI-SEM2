# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# Load the Breast Cancer Wisconsin dataset
data = load_breast_cancer()
X = data.data  # Features
y = data.target  # Labels

# Split the dataset into training and testing

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Train an SVM classifier
svm_model = SVC(kernel='linear', random_state=42)
svm_model.fit(X_train, y_train)

# evL the model on the testing data
y_predi = svm_model.predict(X_test)

# Print evaluation metrics
print("Classification Report:")
print(classification_report(y_test, y_predi))

print("Accuracy Score:", accuracy_score(y_test, y_predi))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94        54
#            1       0.96      0.98      0.97        89
#
#     accuracy                           0.96       143
#    macro avg       0.96      0.95      0.96       143
# weighted avg       0.96      0.96      0.96       143
#
# Accuracy Score: 0.958041958041958

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
import mlflow
import mlflow.sklearn

# Load the Breast Cancer Wisconsin dataset
data = load_breast_cancer()
X = data.data  # Features
y = data.target  # Labels

# Split the dataset into training and testing sets (75-25 split)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Define the hyperparameter grid for SVM
param_grid = {
    'C': [0.1, 1, 10],         # Regularization parameter
    'kernel': ['linear', 'rbf'],  # SVM kernel types
    'gamma': ['scale', 'auto']   # Kernel coefficient for 'rbf'
}

# Initialize the SVM classifier
svm_model = SVC(random_state=42)

# Set up GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, 
                           cv=5, scoring='accuracy', n_jobs=-1, verbose=2)

# Start MLflow experiment
mlflow.start_run()

# Log hyperparameters
mlflow.log_params(param_grid)

# Fit the grid search model
grid_search.fit(X_train, y_train)

# Get the best model from the grid search
best_model = grid_search.best_estimator_

# Log the model to MLflow
mlflow.sklearn.log_model(best_model, "svm_model")

# Predict on the test set using the best model
y_pred = best_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Log metrics to MLflow
mlflow.log_metric("accuracy", accuracy)

# Print the evaluation results
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_rep)

# End MLflow run
mlflow.end_run()
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# 2024/12/08 14:00:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[5], line 47
#      44 best_model = grid_search.best_estimator_
#      46 # Log the model to MLflow
# ---> 47 mlflow.sklearn.log_model(best_model, "svm_model")
#      49 # Predict on the test set using the best model
#      50 y_pred = best_model.predict(X_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\sklearn\__init__.py:413, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata)
#     334 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     335 def log_model(
#     336     sk_model,
#    (...)
#     348     metadata=None,
#     349 ):
#     350     """
#     351     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     352     containing the following flavors:
#    (...)
#     411
#     412     """
# --> 413     return Model.log(
#     414         artifact_path=artifact_path,
#     415         flavor=mlflow.sklearn,
#     416         sk_model=sk_model,
#     417         conda_env=conda_env,
#     418         code_paths=code_paths,
#     419         serialization_format=serialization_format,
#     420         registered_model_name=registered_model_name,
#     421         signature=signature,
#     422         input_example=input_example,
#     423         await_registration_for=await_registration_for,
#     424         pip_requirements=pip_requirements,
#     425         extra_pip_requirements=extra_pip_requirements,
#     426         pyfunc_predict_fn=pyfunc_predict_fn,
#     427         metadata=metadata,
#     428     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\models\model.py:844, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, **kwargs)
#     837     _logger.info(
#     838         "Found the following environment variables used during model inference: "
#     839         f"{env_var_info}. Please check if you need to set them when deploying the "
#     840         "model. To disable this message, set environment variable "
#     841         f"`{MLFLOW_RECORD_ENV_VARS_IN_MODEL_LOGGING.name}` to `false`."
#     842     )
#     843 mlflow_model.env_vars = env_vars
# --> 844 mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path, run_id)
#     846 # if the model_config kwarg is passed in, then log the model config as an params
#     847 if model_config := kwargs.get("model_config"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\tracking\fluent.py:1212, in log_artifacts(local_dir, artifact_path, run_id)
#    1178 """
#    1179 Log all the contents of a local directory as artifacts of the run. If no run is active,
#    1180 this method will create a new active run.
#    (...)
#    1209             mlflow.log_artifacts(tmp_dir, artifact_path="states")
#    1210 """
#    1211 run_id = run_id or _get_or_start_run().info.run_id
# -> 1212 MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\tracking\client.py:1977, in MlflowClient.log_artifacts(self, run_id, local_dir, artifact_path)
#    1930 def log_artifacts(
#    1931     self, run_id: str, local_dir: str, artifact_path: Optional[str] = None
#    1932 ) -> None:
#    1933     """Write a directory of files to the remote ``artifact_uri``.
#    1934
#    1935     Args:
#    (...)
#    1975
#    1976     """
# -> 1977     self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\tracking\_tracking_service\client.py:875, in TrackingServiceClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     866 def log_artifacts(self, run_id, local_dir, artifact_path=None):
#     867     """Write a directory of files to the remote ``artifact_uri``.
#     868
#     869     Args:
#    (...)
#     873
#     874     """
# --> 875     self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\tracking\_tracking_service\client.py:817, in TrackingServiceClient._get_artifact_repo(self, run_id)
#     813 run = self.get_run(run_id)
#     814 artifact_uri = add_databricks_profile_info_to_artifact_uri(
#     815     run.info.artifact_uri, self.tracking_uri
#     816 )
# --> 817 artifact_repo = get_artifact_repository(artifact_uri)
#     818 # Cache the artifact repo to avoid a future network call, removing the oldest
#     819 # entry in the cache if there are too many elements
#     820 if len(utils._artifact_repos_cache) > 1024:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\store\artifact\artifact_repository_registry.py:131, in get_artifact_repository(artifact_uri)
#     118 def get_artifact_repository(artifact_uri: str) -> ArtifactRepository:
#     119     """
#     120     Get an artifact repository from the registry based on the scheme of artifact_uri
#     121
#    (...)
#     129         requirements.
#     130     """
# --> 131     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\store\artifact\artifact_repository_registry.py:76, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      71 if repository is None:
#      72     raise MlflowException(
#      73         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      74         f"Currently registered schemes are: {list(self._registry.keys())}"
#      75     )
# ---> 76 return repository(artifact_uri)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\store\artifact\mlflow_artifacts_repo.py:51, in MlflowArtifactsRepository.__init__(self, artifact_uri)
#      50 def __init__(self, artifact_uri):
# ---> 51     super().__init__(self.resolve_uri(artifact_uri, get_tracking_uri()))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\store\artifact\mlflow_artifacts_repo.py:65, in MlflowArtifactsRepository.resolve_uri(cls, artifact_uri, tracking_uri)
#      62 _validate_port_mapped_to_hostname(uri_parse)
#      64 # Check that tracking uri is http or https
# ---> 65 _validate_uri_scheme(track_parse)
#      67 if uri_parse.path == "/":  # root directory; build simple path
#      68     resolved = f"{base_url}{uri_parse.path}"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mlflow\store\artifact\mlflow_artifacts_repo.py:35, in _validate_uri_scheme(parsed_uri)
#      33 allowable_schemes = {"http", "https"}
#      34 if parsed_uri.scheme not in allowable_schemes:
# ---> 35     raise MlflowException(
#      36         "When an mlflow-artifacts URI was supplied, the tracking URI must be a valid "
#      37         f"http or https URI, but it was currently set to {parsed_uri.geturl()}. "
#      38         "Perhaps you forgot to set the tracking URI to the running MLflow server. "
#      39         "To set the tracking URI, use either of the following methods:\n"
#      40         "1. Set the MLFLOW_TRACKING_URI environment variable to the desired tracking URI. "
#      41         "`export MLFLOW_TRACKING_URI=http://localhost:5000`\n"
#      42         "2. Set the tracking URI programmatically by calling `mlflow.set_tracking_uri`. "
#      43         "`mlflow.set_tracking_uri('http://localhost:5000')`"
#      44     )
#
# MlflowException: When an mlflow-artifacts URI was supplied, the tracking URI must be a valid http or https URI, but it was currently set to file:///C:/Sanjeev/VNIT_CLASSES/SEM2-WORK-GIT/VNIT-AAI-SEM2/SEM-2/DML/WorkSpace/advanced_mlops_env/mlruns. Perhaps you forgot to set the tracking URI to the running MLflow server. To set the tracking URI, use either of the following methods:
# 1. Set the MLFLOW_TRACKING_URI environment variable to the desired tracking URI. `export MLFLOW_TRACKING_URI=http://localhost:5000`
# 2. Set the tracking URI programmatically by calling `mlflow.set_tracking_uri`. `mlflow.set_tracking_uri('http://localhost:5000')`

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
import mlflow
import mlflow.sklearn

# Load the Breast Cancer Wisconsin dataset
data = load_breast_cancer()
X = data.data  # Features
y = data.target  # Labels

# Split the dataset into training and testing sets (75-25 split)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Define the hyperparameter grid for SVM
param_grid = {
    'C': [0.1, 1, 10],         # Regularization parameter
    'kernel': ['linear', 'rbf'],  # SVM kernel types
    'gamma': ['scale', 'auto']   # Kernel coefficient for 'rbf'
}

# Initialize the SVM classifier
svm_model = SVC(random_state=42)

# Set up GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, 
                           cv=5, scoring='accuracy', n_jobs=-1, verbose=2)

# Start MLflow experiment
mlflow.start_run()

# Log hyperparameters
mlflow.log_params(param_grid)

# Fit the grid search model
grid_search.fit(X_train, y_train)

# Get the best model from the grid search
best_model = grid_search.best_estimator_

# Log the model to MLflow
mlflow.sklearn.log_model(best_model, "svm_model")

# Predict on the test set using the best model
y_pred = best_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Log metrics to MLflow
mlflow.log_metric("accuracy", accuracy)

# Print the evaluation results
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_rep)

# End MLflow run
mlflow.end_run()
